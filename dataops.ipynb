# %%
import pandas as pd
import requests
train=pd.read_csv('genres_v2.csv')
train.head()
# Out:
# /var/folders/30/xhkpy5jj7j5g3n783rwcjf300000gn/T/ipykernel_11106/1012550719.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   train=pd.read_csv('genres_v2.csv')
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
train.sort_values(by=['tempo','instrumentalness'])
train.drop(['Unnamed: 0', 'title'], axis=1)
filter = ((train["tempo"] > 30) & (train["tempo"] < 120))
train[filter]
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 20            0.602   0.578    0    -5.610     1       0.0283      0.034300
# 21            0.876   0.768    7    -6.606     1       0.2010      0.112000
# 23            0.829   0.590    9    -7.818     0       0.2630      0.039100
# 24            0.783   0.929   11     0.551     0       0.0893      0.200000
# ...             ...     ...  ...       ...   ...          ...           ...
# 24032         0.760   0.869    2    -8.183     1       0.0775      0.248000
# 24066         0.805   0.407    4   -11.669     0       0.0931      0.002220
# 24174         0.804   0.589    1    -6.749     1       0.0546      0.024300
# 24423         0.654   0.912    8    -2.830     0       0.0296      0.081500
# 24477         0.708   0.604    6   -13.591     0       0.0437      0.000042
#
#        instrumentalness  liveness  valence  ...                      id  \
# 1              0.000000    0.1180    0.124  ...  7pgJBLVz5VmnL7uGHmRj6p
# 20             0.000000    0.1640    0.156  ...  4QhUXx4ON40TIBrZIlnIke
# 21             0.000012    0.2830    0.720  ...  09320vyX4qHd4GjHIpy5w0
# 23             0.010700    0.1140    0.332  ...  0KRKqIJPX6LT9v1ZQGbfn7
# 24             0.004140    0.6890    0.152  ...  0jsbEBnXWgHLkvjV49vYVG
# ...                 ...       ...      ...  ...                     ...
# 24032          0.649000    0.0972    0.516  ...  0GcBDsZ1E9EMWwTjVDriAc
# 24066          0.923000    0.0467    0.561  ...  1BUBjrIXrdI7d1pqslIksN
# 24174          0.733000    0.1150    0.293  ...  3gQK9oKyCU66C8AC9Lh5AE
# 24423          0.002820    0.1500    0.434  ...  4OeW3FtleS18prcxVpNAVX
# 24477          0.639000    0.0489    0.632  ...  6p8i9A3hkXzgk5DMcJyEWg
#
#                                         uri  \
# 1      spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 20     spotify:track:4QhUXx4ON40TIBrZIlnIke
# 21     spotify:track:09320vyX4qHd4GjHIpy5w0
# 23     spotify:track:0KRKqIJPX6LT9v1ZQGbfn7
# 24     spotify:track:0jsbEBnXWgHLkvjV49vYVG
# ...                                     ...
# 24032  spotify:track:0GcBDsZ1E9EMWwTjVDriAc
# 24066  spotify:track:1BUBjrIXrdI7d1pqslIksN
# 24174  spotify:track:3gQK9oKyCU66C8AC9Lh5AE
# 24423  spotify:track:4OeW3FtleS18prcxVpNAVX
# 24477  spotify:track:6p8i9A3hkXzgk5DMcJyEWg
#
#                                               track_href  \
# 1      https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 20     https://api.spotify.com/v1/tracks/4QhUXx4ON40T...
# 21     https://api.spotify.com/v1/tracks/09320vyX4qHd...
# 23     https://api.spotify.com/v1/tracks/0KRKqIJPX6LT...
# 24     https://api.spotify.com/v1/tracks/0jsbEBnXWgHL...
# ...                                                  ...
# 24032  https://api.spotify.com/v1/tracks/0GcBDsZ1E9EM...
# 24066  https://api.spotify.com/v1/tracks/1BUBjrIXrdI7...
# 24174  https://api.spotify.com/v1/tracks/3gQK9oKyCU66...
# 24423  https://api.spotify.com/v1/tracks/4OeW3FtleS18...
# 24477  https://api.spotify.com/v1/tracks/6p8i9A3hkXzg...
#
#                                             analysis_url duration_ms  \
# 1      https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 20     https://api.spotify.com/v1/audio-analysis/4QhU...      186261
# 21     https://api.spotify.com/v1/audio-analysis/0932...      124676
# 23     https://api.spotify.com/v1/audio-analysis/0KRK...      127128
# 24     https://api.spotify.com/v1/audio-analysis/0jsb...      134447
# ...                                                  ...         ...
# 24032  https://api.spotify.com/v1/audio-analysis/0GcB...      364000
# 24066  https://api.spotify.com/v1/audio-analysis/1BUB...      561830
# 24174  https://api.spotify.com/v1/audio-analysis/3gQK...      462015
# 24423  https://api.spotify.com/v1/audio-analysis/4OeW...      193947
# 24477  https://api.spotify.com/v1/audio-analysis/6p8i...      454960
#
#       time_signature      genre       song_name Unnamed: 0  \
# 1                  4  Dark Trap       Pathology        NaN
# 20                 4  Dark Trap          Murder        NaN
# 21                 5  Dark Trap  High 'N Mighty        NaN
# 23                 4  Dark Trap           Hades        NaN
# 24                 4  Dark Trap           Nails        NaN
# ...              ...        ...             ...        ...
# 24032              4  techhouse             NaN     2529.0
# 24066              4  techhouse             NaN     2563.0
# 24174              4  techhouse             NaN     2671.0
# 24423              4  techhouse             NaN     2923.0
# 24477              4  techhouse             NaN     2977.0
#
#                                title
# 1                                NaN
# 20                               NaN
# 21                               NaN
# 23                               NaN
# 24                               NaN
# ...                              ...
# 24032        Tech House by DOT Dance
# 24066                     tech house
# 24174  Dirtybird//Techhouse by Mack\
# 24423                     Tech house
# 24477                     tech house
#
# [3094 rows x 22 columns]

# %%
train["genre"].unique()
# Out:
# array(['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB',
#        'Pop', 'Hiphop', 'techhouse', 'techno', 'trance', 'psytrance',
#        'trap', 'dnb', 'hardstyle'], dtype=object)

# %%
heartrate = 74

# %%
pd.set_option('display.max_colwidth', None)
df_sort = train.iloc[(train['tempo']-heartrate).abs().argsort()[:1]]

df_sort["uri"]
df_sort.iat[0,0]
# Out:
# 0.469

# %%
client_id = '7b14bba7400e4f4c92798c47b15268f8'
redirect_uri = 'http://localhost:8888/callback'

state = generateRandomString(16)

localStorage.setItem(stateKey, state)
scope = 'user-read-private user-read-email'

url = 'https://accounts.spotify.com/authorize'
url += '?response_type=token'
url += '&client_id=' + encodeURIComponent(client_id)
url += '&scope=' + encodeURIComponent(scope)
url += '&redirect_uri=' + encodeURIComponent(redirect_uri)
url += '&state=' + encodeURIComponent(state)
